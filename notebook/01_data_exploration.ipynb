# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent

sys.path.append(str(project_root))

print(project_root)
# Out:
# c:\Projetos\llm-data-intelligence-system

# %%
from src.data.data_loader import OlistDataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.data.data_loader import OlistDataLoader
#
# File c:\Projetos\llm-data-intelligence-system\src\data\data_loader.py:2
#       1 from pathlib import Path
# ----> 2 import pandas as pd
#       5 class OlistDataLoader:
#       6     """
#       7     Responsável pelo carregamento dos dados brutos do dataset Olist.
#       8
#       9     Este módulo não modifica os arquivos originais.
#      10     Apenas realiza leitura e disponibiliza os dados para as próximas etapas.
#      11     """
#
# ModuleNotFoundError: No module named 'pandas'
